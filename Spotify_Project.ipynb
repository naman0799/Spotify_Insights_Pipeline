# %%
import pyodbc
import spotipy
import pandas as pd

# %%
server = r''
database = ''
cnxn = pyodbc.connect(
    f'DRIVER={{ODBC Driver 17 for SQL Server}};'
    f'SERVER={server};'
    f'DATABASE={database};'
    f'Trusted_Connection=yes;'
)
cursor = cnxn.cursor()
print("Connection Successful")
# Out:
# Connection Successful

# %%
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="",
                                               client_secret="",))

# %%
songs = sp.playlist_tracks('5ABHKGoOzxkaa28ttQV9sE', limit = 100)

# %%
songs.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
type(songs['items'])
# Out:
# list

# %%
songs['total']
# Out:
# 100

# %%
type(songs['items'])
# Out:
# list

# %%
songs['items'][0]
# Out:
# {'added_at': '2024-02-15T21:57:53Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/jonathan.holgersson'},
#   'href': 'https://api.spotify.com/v1/users/jonathan.holgersson',
#   'id': 'jonathan.holgersson',
#   'type': 'user',
#   'uri': 'spotify:user:jonathan.holgersson'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
# ...

# %%
songs['items'][0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
songs['items'][0]['track']['album']['name']
# Out:
# 'After Hours'

# %%
songs['items'][99]['track']['album']['name']
# Out:
# 'Please Please Please'

# %%
# this confirms that the data we are getting is correct, now let's add this information in a table

# %%
song = songs['items'][99]

# %%
song['track'].keys()
# Out:
# dict_keys(['preview_url', 'available_markets', 'explicit', 'type', 'episode', 'track', 'album', 'artists', 'disc_number', 'track_number', 'duration_ms', 'external_ids', 'external_urls', 'href', 'id', 'name', 'popularity', 'uri', 'is_local'])

# %%
song['track']['name']
song['track']['id']
song['track']['duration_ms']/(1000)

song['track']['popularity']
song['track']['artists']
song['track']['album']
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
# ...

# %%
track_data = []

for item in songs['items']:
    track = item['track']
    
    track_data.append({
        'track_id': track['id'],
        'track_name': track['name'],
        'artist': track['artists'][0]['name'],
        'album': track['album']['name'],
        'release_date': track['album']['release_date'],
        'popularity': track['popularity'],
        'duration_ms': track['duration_ms'],
        'explicit': track['explicit'],
        'track_url': track['external_urls']['spotify'],
        'album_type': track['album']['album_type']
    })

# %%
df = pd.DataFrame(track_data)
print(df.head())
# Out:
#                  track_id         track_name         artist  \
# 0  0VjIjW4GlUZAMYd2vXMi3b    Blinding Lights     The Weeknd
# 1  7qiZfU4dY1lWllzX7mPBI3       Shape of You     Ed Sheeran
# 2  5aAx2yezTd8zXrkmtKl66Z            Starboy     The Weeknd
# 3  7qEHsqek33rTcFNT9PFqLf  Someone You Loved  Lewis Capaldi
# 4  4Dvkj6JhhA12EX05fT7y2e          As It Was   Harry Styles
#
#                                      album release_date  popularity  \
# 0                              After Hours   2020-03-20          89
# 1                               ÷ (Deluxe)   2017-03-03          89
# 2                                  Starboy   2016-11-25           4
# 3  Divinely Uninspired To A Hellish Extent   2019-05-17          87
# 4                            Harry's House   2022-05-20          88
#
#    duration_ms  explicit                                          track_url  \
# 0       200040     False  https://open.spotify.com/track/0VjIjW4GlUZAMYd...
# ...

# %%
from sqlalchemy import create_engine

engine = create_engine(
    r"mssql+pyodbc://DESKTOP-C0SH0PN\SQL******/Learning_SQL?driver=ODBC+Driver+17+for+SQL+Server")

df.to_sql("spotify_tracks", con=engine, if_exists="replace", index=False)
# Out:
# 100
